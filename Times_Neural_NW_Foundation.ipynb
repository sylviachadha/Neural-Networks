# %% [markdown]
# # Neural Networks

# %% [markdown]
# Neural N/W is one of the secret sauce for implementation of AI. Neural N/W referred to as the brain underneath the AI just like our human brain. Neural n/w is designed/modelled on the human brain. There are neurons in neural n/w & these neurons are arranged in layers.

# %% [markdown]
# A perceptron is another name for a single neuron. A perceptron is simplest neural n/w with Input and 1 neuron.

# %% [markdown]
# The Implementation of artificial neuron n/w boils down to a couple of mathematical operations.

# %% [markdown]
# *Shallow (1 Hidden layer) vs Deep(atleast more than 1 hidden layer)*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Biological vs Artificial Neuron - Basic component of Neural Network

# %% [markdown]
# Neural n/w is designed/modelled on the human brain. Human brain consists of billions of these tiny neurons.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Structure of Artificial Neuron / Perceptron

# %% [markdown]
# A single neuron is called as Perceptron.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## ANN Implementation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Adder Function

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Activation Function

# %% [markdown]
# - The output of your net activation function is actually linear in nature but very often linear functions will not be able to solve most of classification or regression problems so your activation functions offers non-linearity to your model.
# - Sigmoid, Softmax, Relu, linear, tanh etc

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Training in neural n/w is nothing but coming with correct values of weights & biases.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Perceptron - I/P and O/P

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Single layer neural network - I/P, O/P and 1 hidden layer

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Multiple layer neural network - I/P, O/P and many hidden layer

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Perceptron vs Single layer vs Multiple layer neural network

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### MNIST Handwritten Digits Dataset
# Implementation on Single layer & Multi-layer Neural Network with MNIST Digits dataset.
